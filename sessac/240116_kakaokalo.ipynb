# %%
# !pip install PyKakao

# %%
# https://jerry-style.tistory.com/entry/%EC%B9%B4%EC%B9%B4%EC%98%A4-AI-%EC%B9%BC%EB%A1%9C-20-%EC%B5%9C%EC%8B%A0-%EB%B2%84%EC%A0%84-%ED%8C%8C%EC%9D%B4%EC%8D%AC%EC%9C%BC%EB%A1%9C-%EC%82%AC%EC%9A%A9%ED%95%98%EA%B8%B0
# https://developers.kakao.com/docs/latest/ko/karlo/rest-api
from PyKakao import Karlo
key ='25cd96a8acf7223993ff2ee224b480d3'
k = Karlo(service_key=key)
text = '''cat'''
# k.text_to_image(text,1)
k1=k.text_to_image(text,1)
k1
# k1['images'] # 밑에 k1 결과에서 'images': [{'id':'', 'image': '', .......}]만 출력
# Out:
# {'id': '01ddb00c5a08b4a1',
#  'model_version': 'v2.0.4.0.prod',
#  'images': [{'id': 'a2FybG8tdHJpdG9uLTY5NDliOGRjNWYtZnY3Mjg=-d2227b08-4926-401a-bfc4-cc2ef9275df4',
#    'image': 'https://mk.kakaocdn.net/dna/karlo/image/2024-01-16/17/d2227b08-4926-401a-bfc4-cc2ef9275df4.webp?credential=smxRqiqUEJBVgohptvfXS5JoYeFv4Xxa&expires=1705393534&signature=umTiFwknC7D6uYPYIWCg31WPe6o%3D',
#    'seed': 2292068008,
#    'nsfw_content_detected': None,
#    'nsfw_score': None}]}

# %%
# imgDic=k.text_to_image(text,1)
imgDic.keys(),imgDic['images'][0] # 이미지의 url을 떼어오는 거
#'images': [{'id':'', 'image': '', .......}]에서 {'id':'', 'image': '', .......}이것만 떼어오는거
# Out:
# (dict_keys(['id', 'model_version', 'images']),
#  {'id': 'a2FybG8tdHJpdG9uLTY5NDliOGRjNWYtYjRoZ2M=-9f502129-f82d-49a9-819f-3d3eecf023ac',
#   'image': 'https://mk.kakaocdn.net/dna/karlo/image/2024-01-16/17/9f502129-f82d-49a9-819f-3d3eecf023ac.webp?credential=smxRqiqUEJBVgohptvfXS5JoYeFv4Xxa&expires=1705392995&signature=LwpjJJkmIM2dEh6VoYFsoyTpgcA%3D',
#   'seed': 2606124497,
#   'nsfw_content_detected': None,
#   'nsfw_score': None})

# %%
imgUrl=imgDic['images'][0]['image'] # {'id':'', 'image': '', .......}에서 image 안에 url만 가져오는거 
imgUrl
import requests
imgData=requests.get(imgUrl, stream=True).raw
from PIL import Image
img=Image.open(imgData)
img
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=512x512>
